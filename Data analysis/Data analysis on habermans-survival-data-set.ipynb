# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset = pd.read_csv('haberman.csv')
dataset.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
dataset.shape
# Out:
# (305, 4)

# %%
dataset['1.1'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
dataset = dataset.rename(columns = {'1.1':'status','30':'age','64':'op_year',
                                    '1':'axil_nodes'})

# %%
# ?dataset.rename

# %%
dataset.head()
# Out:
#    age  op_year  axil_nodes  status
# 0   30       62           3       1
# 1   30       65           0       1
# 2   31       59           2       1
# 3   31       65           4       1
# 4   33       58          10       1

# %%
sns.set_style('whitegrid')
sns.FacetGrid(dataset, hue='status', height=8) \
   .map(plt.scatter,'age','op_year') \
    .add_legend()

# %%
sns.pairplot(dataset, hue='status', height = 8)

# %%
dataset['status'].value_counts()
# Out:
# 1    224
# 2     81
# Name: status, dtype: int64

# %%
dataset_survived = dataset[dataset['status']==1]
dataset_died = dataset[dataset['status']==2]

# %%
dataset_survived.head()
# Out:
#    age  op_year  axil_nodes  status
# 0   30       62           3       1
# 1   30       65           0       1
# 2   31       59           2       1
# 3   31       65           4       1
# 4   33       58          10       1

# %%
dataset_died.head()
# Out:
#     age  op_year  axil_nodes  status
# 6    34       59           0       2
# 7    34       66           9       2
# 23   38       69          21       2
# 33   39       66           0       2
# 42   41       60          23       2

# %%
sns.boxplot(x = 'status', y = 'age' , data = dataset)

# %%
sns.violinplot(x='status', y = 'axil_nodes', data = dataset)

# %%
sns.jointplot(x='age',y='op_year', data=dataset, kind='kde')
